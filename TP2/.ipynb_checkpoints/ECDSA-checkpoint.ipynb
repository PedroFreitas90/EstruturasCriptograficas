# %% [markdown]
# ## Verificação da curva elíptica
#
# * **Verificar se G tem ordem n**
# * **Verificar a estrutura de grupo abeliano na órbita de G**
# * **Verificar se P aleatório está na órbita de G é equivalente a resolver o problema de logaritmo discreto na curva**

# %%
class ECDSA():
    global NIST
    NIST = dict()
    NIST['P-384'] = {
        'p': 39402006196394479212279040100143613805079739270465446667948293404245721771496870329047266088258938001861606973112319,
        'n': 39402006196394479212279040100143613805079739270465446667948293404245721771496870329047266088258938001861606973112319,
        'seed': 'a335926aa319a27a1d00896a6773a4827acdac73',
        'c': '79d1e655f868f02fff48dcdee14151ddb80643c1406d0ca10dfe6fc52009540a495e8042ea5f744f6e184667cc722483',
        'b': 'b3312fa7e23ee7e4988e056be3f82d19181d9c6efe8141120314088f5013875ac656398d8a2ed19d2a85c8edd3ec2aef',
        'Gx': 'aa87ca22be8b05378eb1c71ef320ad746e1d3b628ba79b9859f741e082542a385502f25dbf55296c3a545e3872760ab7',
        'Gy': '3617de4a96262c6f5d9e98bf9292dc29f8f41dbd289a147ce9da3113b5f0b8c00a60b1ce1d7e819d7a431d7c90ea0e5f'
    }
    '''
        Para cada primo p, uma curva pseudo-aleatória:
            E: y^2 = x^3 - 3x + b (mod p)
            
    '''
    
    
    def verify(self):
        p = NIST['P-384']['p']
        n = NIST['P-384']['n']
        b = ZZ(NIST['P-384']['b'], 16) #Converte a string de base16 em inteiro
        gx = ZZ(NIST['P-384']['Gx'], 16) #Converte a string de base16 em inteiro
        gy = ZZ(NIST['P-384']['Gy'], 16) #Converte a string de base16 em inteiro
        
        #Curva pseudo-aleatoria
        E = EllipticCurve(GF(p),[-3,b])
        print('Curva pseudo-aleatória E: ')
        print(E)
        print('-----------------------------')
        
        #Órbita de G
        G = E((gx,gy))
        print('Órbita G: ')
        print(G)
        print('-----------------------------')
        
        nn= 123
        # Verificar ordem de G
        print(G*n)
        # Verificar a estrutura de grupo abeliano na órbita de G
        i = ZZ.random_element(1,n-1)
        j = ZZ.random_element(1,n-1)
        z = 456
        print (G*i, G*j)  
        print (G*i + G*j)
        print (G*(i+j))

# %%
x = ECDSA()

x.verify()
# Out:
# Curva pseudo-aleatória E:
# Elliptic Curve defined by y^2 = x^3 + 39402006196394479212279040100143613805079739270465446667948293404245721771496870329047266088258938001861606973112316*x + 27580193559959705877849011840389048093056905856361568521428707301988689241309860865136260764883745107765439761230575 over Finite Field of size 39402006196394479212279040100143613805079739270465446667948293404245721771496870329047266088258938001861606973112319
# -----------------------------
# Órbita G:
# (26247035095799689268623156744566981891852923491109213387815615900925518854738050089022388053975719786650872476732087 : 8325710961489029985546751289520108179287853048861315594709205902480503199884419224438643760392947333078086511627871 : 1)
# -----------------------------
# ...

# %%
p = NIST['P-384']['p']
n = NIST['P-384']['n']
b = NIST['P-384']['b']
Gx = NIST['P-384']['Gx']
print(type(Gx))
Gy = NIST['P-384']['Gy']

bb = ZZ(b,16)
print('b: ' + str(b))
print('bb: ' + str(bb))

gx = ZZ(NIST['P-384']['Gx'], 16)
print('gx: ' + str(gx))

gy = ZZ(NIST['P-384']['Gy'], 16)
print('gy: ' + str(gy))
print(type(gy))


x = 90
print(type(x))
# Out:
# <type 'str'>
# b: b3312fa7e23ee7e4988e056be3f82d19181d9c6efe8141120314088f5013875ac656398d8a2ed19d2a85c8edd3ec2aef
# bb: 27580193559959705877849011840389048093056905856361568521428707301988689241309860865136260764883745107765439761230575
# gx: 26247035095799689268623156744566981891852923491109213387815615900925518854738050089022388053975719786650872476732087
# gy: 8325710961489029985546751289520108179287853048861315594709205902480503199884419224438643760392947333078086511627871
# <type 'sage.rings.integer.Integer'>
# <type 'sage.rings.integer.Integer'>

# %%
p = NIST['P-384']['p']
D = EllipticCurve(GF(p),[-3,5])
print(D)
# Out:
# Elliptic Curve defined by y^2 = x^3 + 39402006196394479212279040100143613805079739270465446667948293404245721771496870329047266088258938001861606973112316*x + 5 over Finite Field of size 39402006196394479212279040100143613805079739270465446667948293404245721771496870329047266088258938001861606973112319

# %%
b = ZZ(NIST['P-384']['b'],16)
E = EllipticCurve(GF(p),[-3,b])
print(E)

print('------------')
gx = ZZ(NIST['P-384']['Gx'], 16)
gy = ZZ(NIST['P-384']['Gy'], 16)
print('------------')
G = E((gx,gy))
print(G)
